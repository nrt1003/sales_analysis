# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %%
import sys
sys.path.insert(1, '../src')
import nikitas_work

# %%
contract,cust = nikitas_work.load_data()
contract.head()
# Out:
#    contract_id  customer_id contract_start  contract_term     deposit  \
# 0            1          127      8/17/2019             12  $53,000.00
# 1            2          119      12/1/2019             22  $77,000.00
# 2            3          160       5/1/2019             15  $13,000.00
# 3            4            7      12/8/2019             23  $56,000.00
# 4            5          144      2/11/2019              7  $21,000.00
#
#   monthly_amt
# 0  $11,600.00
# 1  $14,600.00
# 2  $22,800.00
# 3  $11,400.00
# 4  $19,800.00

# %%
cust.head()
# Out:
#    id       company         sector                                 industry  \
# 0   1     Bubblebox  Capital Goods            Military/Government/Technical
# 1   2          Izio         Energy                     Oil & Gas Production
# 2   3  Twitterworks            NaN                                      NaN
# 3   4          Viva    Health Care                    Major Pharmaceuticals
# 4   5   Jabberstorm     Technology  Computer Software: Prepackaged Software
#
#                       email                     address         city state  \
# 0  kyerson0@bizjournals.com             76 Randy Circle    San Diego    CA
# 1       farlet1@comcast.net  15360 Village Green Street      Spokane    WA
# 2        alerohan2@ox.ac.uk               29 Hovde Hill    Milwaukee    WI
# 3  wgiovanitti3@nytimes.com            074 Center Place       Topeka    KS
# 4         pscallon4@fc2.com                 4 Moose Way  Terre Haute    IN
#
#      zip
# 0  92170
# 1  99252
# 2  53234
# 3  66667
# ...

# %%
df = nikitas_work.combine_data(contract, cust)
df.head()
# Out:
#              contract_id contract_start  contract_term     deposit  \
# customer_id
# 1                     41      5/31/2019             24  $86,000.00
# 1                    358      6/18/2019             13  $74,000.00
# 1                    400      8/11/2019             19  $38,000.00
# 1                    424      3/13/2019             15  $77,000.00
# 1                    438     10/16/2019             22  $39,000.00
#
#             monthly_amt    company         sector  \
# customer_id
# 1            $11,200.00  Bubblebox  Capital Goods
# 1            $19,000.00  Bubblebox  Capital Goods
# 1             $8,800.00  Bubblebox  Capital Goods
# 1            $14,300.00  Bubblebox  Capital Goods
# 1            $20,000.00  Bubblebox  Capital Goods
#
#                                   industry                     email  \
# customer_id
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# ...

# %%
Data = {'Deposit': ['86000','74000','38000','77000','39000'],
        'Month_Amount': ['11,200','19,000','8800','14300','20000']}
df = pd.DataFrame(Data)
df['Deposit'] = df['Deposit'].astype(int)
print(df)
# Out:
#    Deposit Month_Amount
# 0    86000       11,200
# 1    74000       19,000
# 2    38000         8800
# 3    77000        14300
# 4    39000        20000

# %%
df_contracts = pd.read_csv('../data/contracts.csv')
df
# Out:
#    Deposit Month_Amount
# 0    86000       11,200
# 1    74000       19,000
# 2    38000         8800
# 3    77000        14300
# 4    39000        20000

# %%
join_df = pd.merge(contract, cust, left_on='customer_id', right_on='id')
join_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-5dc7c0bc0f38> in <module>
# ----> 1 join_df = pd.merge(contract, cust, left_on='customer_id', right_on='id')
#       2 join_df
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
# ...

# %%
join_df['deposit'] = join_df['deposit'].str.replace('$', '')
join_df['deposit'] = join_df['deposit'].str.replace(',', '').astype(float)

join_df['monthly_amt'] = join_df['monthly_amt'].str.replace('$', '')
join_df['monthly_amt'] = join_df['monthly_amt'].str.replace(',', '').astype(float)

join_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9f664887c152> in <module>
# ----> 1 join_df['deposit'] = join_df['deposit'].str.replace('$', '')
#       2 join_df['deposit'] = join_df['deposit'].str.replace(',', '').astype(float)
#       3
#       4 join_df['monthly_amt'] = join_df['monthly_amt'].str.replace('$', '')
#       5 join_df['monthly_amt'] = join_df['monthly_amt'].str.replace(',', '').astype(float)
#
# NameError: name 'join_df' is not defined

# %%
join_df['sale'] = pd.Series(join_df['deposit']+join_df['monthly_amt']*join_df['contract_term'])
join_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fe6b31830592> in <module>
# ----> 1 join_df['sale'] = pd.Series(join_df['deposit']+join_df['monthly_amt']*join_df['contract_term'])
#       2 join_df
#
# NameError: name 'join_df' is not defined

# %%
join_df.groupby('state').agg({'sale': 'sum'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-047c38e1b294> in <module>
# ----> 1 join_df.groupby('state').agg({'sale': 'sum'})
#
# NameError: name 'join_df' is not defined
